# %%
# add the pandas dependency
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
# DB String
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/clean_vaccine_data"

# %%
# Create database engine
engine = create_engine(db_string)

# %%
# read and load the csv file store in data frame
file_path = 'Resources/merged_Vaccine_Hesitancy.csv'
Vaccine_Hesitancy_df = pd.read_csv(file_path)
Vaccine_Hesitancy_df.head()
# Out:
#    fips_code                     county_name   states  percent_hispanic  \
# 0       1131          Wilcox County, Alabama  ALABAMA            0.0053
# 1       1129      Washington County, Alabama  ALABAMA            0.0146
# 2       1133         Winston County, Alabama  ALABAMA            0.0315
# 3       1127          Walker County, Alabama  ALABAMA            0.0249
# 4       2013  Aleutians East Borough, Alaska   ALASKA            0.0901
#
#    percent_non_hispanic_american_indianalaska_native  \
# 0                                             0.0009
# 1                                             0.0731
# 2                                             0.0034
# 3                                             0.0015
# 4                                             0.4588
#
#    percent_non_hispanic_asian  percent_non_hispanic_black  \
# 0                      0.0003                      0.6938
# 1                      0.0025                      0.2354
# 2                      0.0016                      0.0073
# 3                      0.0049                      0.0617
# 4                      0.1968                      0.0322
#
#    percent_non_hispanic_native_hawaiianpacific_islander  \
# 0                                             0.0000
# 1                                             0.0000
# 2                                             0.0005
# 3                                             0.0000
# 4                                             0.0100
#
#    percent_non_hispanic_white             geographical_point  \
# 0                      0.2684   POINT (-86.844516 32.756889)
# 1                      0.6495   POINT (-86.844516 32.756889)
# 2                      0.9370   POINT (-86.844516 32.756889)
# 3                      0.8895   POINT (-86.844516 32.756889)
# 4                      0.1321  POINT (-151.631889 63.631126)
#
#    social_vulnerability_index       svi_category  \
# 0                        0.93  Very High Concern
# 1                        0.73       High Concern
# 2                        0.70       High Concern
# 3                        0.75       High Concern
# 4                        0.58   Moderate Concern
#
#    cvac_level_of_concern_for_vaccination_rollout cvac_level_of_concern  \
# 0                                           0.94     Very High Concern
# 1                                           0.82     Very High Concern
# 2                                           0.80          High Concern
# 3                                           0.68          High Concern
# 4                                           0.87     Very High Concern
#
#    percent_adults_fully_vaccinated_against_covid19 state_code  \
# 0                                            0.228         AL
# 1                                            0.192         AL
# 2                                            0.085         AL
# 3                                            0.158         AL
# 4                                            0.195         AK
#
#                                      county_boundary  \
# 0  MULTIPOLYGON (((-87.52534299999999 32.132773, ...
# 1  MULTIPOLYGON (((-88.45317899999999 31.505388, ...
# 2  MULTIPOLYGON (((-87.63656399999999 34.120908, ...
# 3  MULTIPOLYGON (((-87.56108499999999 33.868713, ...
# 4  MULTIPOLYGON (((-165.036163 54.576598, -165.01...
#
#                                       state_boundary  estimated_hesitant  \
# 0  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                0.23
# 1  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                0.23
# 2  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                0.22
# 3  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                0.23
# 4  MULTIPOLYGON (((-165.254162 60.917108, -165.30...                0.26
#
#    estimated_strongly_hesitant
# 0                         0.11
# 1                         0.11
# 2                         0.11
# 3                         0.11
# 4                         0.12

# %%
# check and see the columns data type
Vaccine_Hesitancy_df.dtypes
# Out:
# fips_code                                                 int64
# county_name                                              object
# states                                                   object
# percent_hispanic                                        float64
# percent_non_hispanic_american_indianalaska_native       float64
# percent_non_hispanic_asian                              float64
# percent_non_hispanic_black                              float64
# percent_non_hispanic_native_hawaiianpacific_islander    float64
# percent_non_hispanic_white                              float64
# geographical_point                                       object
# social_vulnerability_index                              float64
# svi_category                                             object
# cvac_level_of_concern_for_vaccination_rollout           float64
# cvac_level_of_concern                                    object
# percent_adults_fully_vaccinated_against_covid19         float64
# state_code                                               object
# county_boundary                                          object
# state_boundary                                           object
# estimated_hesitant                                      float64
# estimated_strongly_hesitant                             float64
# dtype: object

# %%
# select the important columns we interested
Vaccine_Hesitancy_df = Vaccine_Hesitancy_df.drop(columns=['fips_code','county_name','state_boundary','county_boundary','geographical_point','state_code', 'estimated_strongly_hesitant'])
Vaccine_Hesitancy_df
# Out:
#          states  percent_hispanic  \
# 0       ALABAMA            0.0053
# 1       ALABAMA            0.0146
# 2       ALABAMA            0.0315
# 3       ALABAMA            0.0249
# 4        ALASKA            0.0901
# ...         ...               ...
# 3137  WISCONSIN            0.1500
# 3138  WISCONSIN            0.0840
# 3139    WYOMING            0.0953
# 3140  WISCONSIN            0.0197
# 3141  WISCONSIN            0.0177
#
#       percent_non_hispanic_american_indianalaska_native  \
# 0                                                0.0009
# 1                                                0.0731
# 2                                                0.0034
# 3                                                0.0015
# 4                                                0.4588
# ...                                                 ...
# 3137                                             0.0047
# 3138                                             0.0034
# 3139                                             0.0091
# 3140                                             0.0069
# 3141                                             0.0096
#
#       percent_non_hispanic_asian  percent_non_hispanic_black  \
# 0                         0.0003                      0.6938
# 1                         0.0025                      0.2354
# 2                         0.0016                      0.0073
# 3                         0.0049                      0.0617
# 4                         0.1968                      0.0322
# ...                          ...                         ...
# 3137                      0.0428                      0.2606
# 3138                      0.0043                      0.0051
# 3139                      0.0327                      0.0150
# 3140                      0.0022                      0.0125
# 3141                      0.0060                      0.0083
#
#       percent_non_hispanic_native_hawaiianpacific_islander  \
# 0                                                0.0000
# 1                                                0.0000
# 2                                                0.0005
# 3                                                0.0000
# 4                                                0.0100
# ...                                                 ...
# 3137                                             0.0002
# 3138                                             0.0000
# 3139                                             0.0003
# 3140                                             0.0002
# 3141                                             0.0085
#
#       percent_non_hispanic_white  social_vulnerability_index  \
# 0                         0.2684                        0.93
# 1                         0.6495                        0.73
# 2                         0.9370                        0.70
# 3                         0.8895                        0.75
# 4                         0.1321                        0.58
# ...                          ...                         ...
# 3137                      0.5124                        0.81
# 3138                      0.8953                        0.28
# 3139                      0.8248                        0.25
# 3140                      0.9383                        0.35
# 3141                      0.9407                        0.16
#
#            svi_category  cvac_level_of_concern_for_vaccination_rollout  \
# 0     Very High Concern                                           0.94
# 1          High Concern                                           0.82
# 2          High Concern                                           0.80
# 3          High Concern                                           0.68
# 4      Moderate Concern                                           0.87
# ...                 ...                                            ...
# 3137  Very High Concern                                           0.30
# 3138        Low Concern                                           0.31
# 3139        Low Concern                                           0.63
# 3140        Low Concern                                           0.19
# 3141   Very Low Concern                                           0.20
#
#      cvac_level_of_concern  percent_adults_fully_vaccinated_against_covid19  \
# 0        Very High Concern                                            0.228
# 1        Very High Concern                                            0.192
# 2             High Concern                                            0.085
# 3             High Concern                                            0.158
# 4        Very High Concern                                            0.195
# ...                    ...                                              ...
# 3137           Low Concern                                            0.195
# 3138           Low Concern                                            0.294
# 3139          High Concern                                            0.192
# 3140      Very Low Concern                                            0.210
# 3141      Very Low Concern                                            0.223
#
#       estimated_hesitant
# 0                   0.23
# 1                   0.23
# 2                   0.22
# 3                   0.23
# 4                   0.26
# ...                  ...
# 3137                0.18
# 3138                0.18
# 3139                0.30
# 3140                0.17
# 3141                0.17
#
# [3142 rows x 13 columns]

# %%
# see any null value in the df
Vaccine_Hesitancy_df.isnull().sum()
# Out:
# states                                                    0
# percent_hispanic                                          0
# percent_non_hispanic_american_indianalaska_native         0
# percent_non_hispanic_asian                                0
# percent_non_hispanic_black                                0
# percent_non_hispanic_native_hawaiianpacific_islander      0
# percent_non_hispanic_white                                0
# social_vulnerability_index                                1
# svi_category                                              0
# cvac_level_of_concern_for_vaccination_rollout             0
# cvac_level_of_concern                                     0
# percent_adults_fully_vaccinated_against_covid19         316
# estimated_hesitant                                        0
# dtype: int64

# %%
# to see whats the look like for the row have null value 
Vaccine_Hesitancy_df[Vaccine_Hesitancy_df.isnull().any(axis=1)]
# Out:
#         states  percent_hispanic  \
# 19      HAWAII            0.1273
# 24      HAWAII            0.0985
# 27      HAWAII            0.0303
# 105      TEXAS            0.1879
# 106      TEXAS            0.6022
# ...        ...               ...
# 2981  VIRGINIA            0.0587
# 2989  VIRGINIA            0.3973
# 3008  VIRGINIA            0.0180
# 3011  VIRGINIA            0.0612
# 3019  VIRGINIA            0.1450
#
#       percent_non_hispanic_american_indianalaska_native  \
# 19                                               0.0018
# 24                                               0.0013
# 27                                               0.0152
# 105                                              0.0035
# 106                                              0.0016
# ...                                                 ...
# 2981                                             0.0029
# 2989                                             0.0000
# 3008                                             0.0009
# 3011                                             0.0000
# 3019                                             0.0000
#
#       percent_non_hispanic_asian  percent_non_hispanic_black  \
# 19                        0.2184                      0.0058
# 24                        0.4173                      0.0225
# 27                        0.2121                      0.0303
# 105                       0.0028                      0.0069
# 106                       0.0274                      0.0710
# ...                          ...                         ...
# 2981                      0.0415                      0.1464
# 2989                      0.1109                      0.1278
# 3008                      0.0190                      0.0728
# 3011                      0.0345                      0.0867
# 3019                      0.0064                      0.0497
#
#       percent_non_hispanic_native_hawaiianpacific_islander  \
# 19                                               0.1108
# 24                                               0.0893
# 27                                               0.2727
# 105                                              0.0000
# 106                                              0.0009
# ...                                                 ...
# 2981                                             0.0000
# 2989                                             0.0000
# 3008                                             0.0025
# 3011                                             0.0000
# 3019                                             0.0025
#
#       percent_non_hispanic_white  social_vulnerability_index  \
# 19                        0.3031                        0.58
# 24                        0.1837                        0.47
# 27                        0.2273                        0.32
# 105                       0.7783                        0.51
# 106                       0.2767                        0.83
# ...                          ...                         ...
# 2981                      0.7232                        0.57
# 2989                      0.3309                        0.53
# 3008                      0.8812                        0.32
# 3011                      0.7912                        0.32
# 3019                      0.7909                        0.98
#
#            svi_category  cvac_level_of_concern_for_vaccination_rollout  \
# 19     Moderate Concern                                           0.35
# 24     Moderate Concern                                           0.30
# 27          Low Concern                                           0.57
# 105    Moderate Concern                                           0.77
# 106   Very High Concern                                           0.87
# ...                 ...                                            ...
# 2981   Moderate Concern                                           0.25
# 2989   Moderate Concern                                           0.28
# 3008        Low Concern                                           0.36
# 3011        Low Concern                                           0.39
# 3019  Very High Concern                                           0.46
#
#      cvac_level_of_concern  percent_adults_fully_vaccinated_against_covid19  \
# 19             Low Concern                                              NaN
# 24             Low Concern                                              NaN
# 27        Moderate Concern                                              NaN
# 105           High Concern                                              NaN
# 106      Very High Concern                                              NaN
# ...                    ...                                              ...
# 2981           Low Concern                                              NaN
# 2989           Low Concern                                              NaN
# 3008           Low Concern                                              NaN
# 3011           Low Concern                                              NaN
# 3019      Moderate Concern                                              NaN
#
#       estimated_hesitant
# 19                  0.12
# 24                  0.10
# 27                  0.11
# 105                 0.17
# 106                 0.16
# ...                  ...
# 2981                0.18
# 2989                0.15
# 3008                0.17
# 3011                0.17
# 3019                0.17
#
# [316 rows x 13 columns]

# %%
# replace null value with 0
Vaccine_Hesitancy_df = Vaccine_Hesitancy_df.fillna(0)
Vaccine_Hesitancy_df.isnull().sum()
# Out:
# states                                                  0
# percent_hispanic                                        0
# percent_non_hispanic_american_indianalaska_native       0
# percent_non_hispanic_asian                              0
# percent_non_hispanic_black                              0
# percent_non_hispanic_native_hawaiianpacific_islander    0
# percent_non_hispanic_white                              0
# social_vulnerability_index                              0
# svi_category                                            0
# cvac_level_of_concern_for_vaccination_rollout           0
# cvac_level_of_concern                                   0
# percent_adults_fully_vaccinated_against_covid19         0
# estimated_hesitant                                      0
# dtype: int64

# %%
# Saving cleaned data
file_path = "Resources/visual_vaccine_hesitancy_clean.csv"
Vaccine_Hesitancy_df.to_csv(file_path, index=False)

# %%
# Connect DB to SQL
Vaccine_Hesitancy_df.to_sql(name='visual_vaccine_hesitancy_clean', con=engine,if_exists='replace')

# %%
# add the pandas dependency
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
# DB String
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/clean_vaccine_data"

# %%
# Create database engine
engine = create_engine(db_string)

# %%
# read and load the csv file store in data frame
file_path = 'Resources/merged_Vaccine_Hesitancy.csv'
Vaccine_Hesitancy_df = pd.read_csv(file_path)
Vaccine_Hesitancy_df.head()
# Out:
#    fips_code                     county_name   states  percent_hispanic  \
# 0       1131          Wilcox County, Alabama  ALABAMA            0.0053
# 1       1129      Washington County, Alabama  ALABAMA            0.0146
# 2       1133         Winston County, Alabama  ALABAMA            0.0315
# 3       1127          Walker County, Alabama  ALABAMA            0.0249
# 4       2013  Aleutians East Borough, Alaska   ALASKA            0.0901
#
#    percent_non_hispanic_american_indianalaska_native  \
# 0                                             0.0009
# 1                                             0.0731
# 2                                             0.0034
# 3                                             0.0015
# 4                                             0.4588
#
#    percent_non_hispanic_asian  percent_non_hispanic_black  \
# 0                      0.0003                      0.6938
# 1                      0.0025                      0.2354
# 2                      0.0016                      0.0073
# 3                      0.0049                      0.0617
# 4                      0.1968                      0.0322
#
#    percent_non_hispanic_native_hawaiianpacific_islander  \
# 0                                             0.0000
# 1                                             0.0000
# 2                                             0.0005
# 3                                             0.0000
# 4                                             0.0100
#
#    percent_non_hispanic_white             geographical_point  \
# 0                      0.2684   POINT (-86.844516 32.756889)
# 1                      0.6495   POINT (-86.844516 32.756889)
# 2                      0.9370   POINT (-86.844516 32.756889)
# 3                      0.8895   POINT (-86.844516 32.756889)
# 4                      0.1321  POINT (-151.631889 63.631126)
#
#    social_vulnerability_index       svi_category  \
# 0                        0.93  Very High Concern
# 1                        0.73       High Concern
# 2                        0.70       High Concern
# 3                        0.75       High Concern
# 4                        0.58   Moderate Concern
#
#    cvac_level_of_concern_for_vaccination_rollout cvac_level_of_concern  \
# 0                                           0.94     Very High Concern
# 1                                           0.82     Very High Concern
# 2                                           0.80          High Concern
# 3                                           0.68          High Concern
# 4                                           0.87     Very High Concern
#
#    percent_adults_fully_vaccinated_against_covid19 state_code  \
# 0                                            0.228         AL
# 1                                            0.192         AL
# 2                                            0.085         AL
# 3                                            0.158         AL
# 4                                            0.195         AK
#
#                                      county_boundary  \
# 0  MULTIPOLYGON (((-87.52534299999999 32.132773, ...
# 1  MULTIPOLYGON (((-88.45317899999999 31.505388, ...
# 2  MULTIPOLYGON (((-87.63656399999999 34.120908, ...
# 3  MULTIPOLYGON (((-87.56108499999999 33.868713, ...
# 4  MULTIPOLYGON (((-165.036163 54.576598, -165.01...
#
#                                       state_boundary  estimated_hesitant  \
# 0  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                0.23
# 1  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                0.23
# 2  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                0.22
# 3  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...                0.23
# 4  MULTIPOLYGON (((-165.254162 60.917108, -165.30...                0.26
#
#    estimated_strongly_hesitant
# 0                         0.11
# 1                         0.11
# 2                         0.11
# 3                         0.11
# 4                         0.12

# %%
# check and see the columns data type
Vaccine_Hesitancy_df.dtypes
# Out:
# fips_code                                                 int64
# county_name                                              object
# states                                                   object
# percent_hispanic                                        float64
# percent_non_hispanic_american_indianalaska_native       float64
# percent_non_hispanic_asian                              float64
# percent_non_hispanic_black                              float64
# percent_non_hispanic_native_hawaiianpacific_islander    float64
# percent_non_hispanic_white                              float64
# geographical_point                                       object
# social_vulnerability_index                              float64
# svi_category                                             object
# cvac_level_of_concern_for_vaccination_rollout           float64
# cvac_level_of_concern                                    object
# percent_adults_fully_vaccinated_against_covid19         float64
# state_code                                               object
# county_boundary                                          object
# state_boundary                                           object
# estimated_hesitant                                      float64
# estimated_strongly_hesitant                             float64
# dtype: object

# %%
# select the important columns we interested
Vaccine_Hesitancy_df = Vaccine_Hesitancy_df.drop(columns=['fips_code','county_name', 'states', 'svi_category', 'cvac_level_of_concern','state_boundary','county_boundary','geographical_point','state_code', 'estimated_strongly_hesitant','percent_adults_fully_vaccinated_against_covid19'])
Vaccine_Hesitancy_df
# Out:
#       percent_hispanic  percent_non_hispanic_american_indianalaska_native  \
# 0               0.0053                                             0.0009
# 1               0.0146                                             0.0731
# 2               0.0315                                             0.0034
# 3               0.0249                                             0.0015
# 4               0.0901                                             0.4588
# ...                ...                                                ...
# 3137            0.1500                                             0.0047
# 3138            0.0840                                             0.0034
# 3139            0.0953                                             0.0091
# 3140            0.0197                                             0.0069
# 3141            0.0177                                             0.0096
#
#       percent_non_hispanic_asian  percent_non_hispanic_black  \
# 0                         0.0003                      0.6938
# 1                         0.0025                      0.2354
# 2                         0.0016                      0.0073
# 3                         0.0049                      0.0617
# 4                         0.1968                      0.0322
# ...                          ...                         ...
# 3137                      0.0428                      0.2606
# 3138                      0.0043                      0.0051
# 3139                      0.0327                      0.0150
# 3140                      0.0022                      0.0125
# 3141                      0.0060                      0.0083
#
#       percent_non_hispanic_native_hawaiianpacific_islander  \
# 0                                                0.0000
# 1                                                0.0000
# 2                                                0.0005
# 3                                                0.0000
# 4                                                0.0100
# ...                                                 ...
# 3137                                             0.0002
# 3138                                             0.0000
# 3139                                             0.0003
# 3140                                             0.0002
# 3141                                             0.0085
#
#       percent_non_hispanic_white  social_vulnerability_index  \
# 0                         0.2684                        0.93
# 1                         0.6495                        0.73
# 2                         0.9370                        0.70
# 3                         0.8895                        0.75
# 4                         0.1321                        0.58
# ...                          ...                         ...
# 3137                      0.5124                        0.81
# 3138                      0.8953                        0.28
# 3139                      0.8248                        0.25
# 3140                      0.9383                        0.35
# 3141                      0.9407                        0.16
#
#       cvac_level_of_concern_for_vaccination_rollout  estimated_hesitant
# 0                                              0.94                0.23
# 1                                              0.82                0.23
# 2                                              0.80                0.22
# 3                                              0.68                0.23
# 4                                              0.87                0.26
# ...                                             ...                 ...
# 3137                                           0.30                0.18
# 3138                                           0.31                0.18
# 3139                                           0.63                0.30
# 3140                                           0.19                0.17
# 3141                                           0.20                0.17
#
# [3142 rows x 9 columns]

# %%
# see any null value in the df
Vaccine_Hesitancy_df.isnull().sum()
# Out:
# percent_hispanic                                        0
# percent_non_hispanic_american_indianalaska_native       0
# percent_non_hispanic_asian                              0
# percent_non_hispanic_black                              0
# percent_non_hispanic_native_hawaiianpacific_islander    0
# percent_non_hispanic_white                              0
# social_vulnerability_index                              1
# cvac_level_of_concern_for_vaccination_rollout           0
# estimated_hesitant                                      0
# dtype: int64

# %%
# to see whats the look like for the row have null value 
Vaccine_Hesitancy_df[Vaccine_Hesitancy_df.isnull().any(axis=1)]
# Out:
#       percent_hispanic  percent_non_hispanic_american_indianalaska_native  \
# 1971            0.7124                                             0.1431
#
#       percent_non_hispanic_asian  percent_non_hispanic_black  \
# 1971                      0.0048                      0.0044
#
#       percent_non_hispanic_native_hawaiianpacific_islander  \
# 1971                                             0.0003
#
#       percent_non_hispanic_white  social_vulnerability_index  \
# 1971                      0.1244                         NaN
#
#       cvac_level_of_concern_for_vaccination_rollout  estimated_hesitant
# 1971                                           0.62                0.12

# %%
# replace null value with 0
Vaccine_Hesitancy_df = Vaccine_Hesitancy_df.fillna(0)
Vaccine_Hesitancy_df.isnull().sum()
# Out:
# percent_hispanic                                        0
# percent_non_hispanic_american_indianalaska_native       0
# percent_non_hispanic_asian                              0
# percent_non_hispanic_black                              0
# percent_non_hispanic_native_hawaiianpacific_islander    0
# percent_non_hispanic_white                              0
# social_vulnerability_index                              0
# cvac_level_of_concern_for_vaccination_rollout           0
# estimated_hesitant                                      0
# dtype: int64

# %%
# Saving cleaned data
file_path = "Resources/vaccine_hesitancy_clean.csv"
Vaccine_Hesitancy_df.to_csv(file_path, index=False)

# %%
# Connect DB to SQL
Vaccine_Hesitancy_df.to_sql(name='vaccine_hesitancy_clean', con=engine)
